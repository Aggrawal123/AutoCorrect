# %%
import string
import re
import numpy as np
from collections import Counter

# %%
def read_corpus(filename):
    with open(filename,'r',encoding='utf-8') as file:
        lines = file.readlines()
        
        words = []
        for word in lines:
            words += re.findall(r'\w+',word.lower())
    return words

# invoke this function
corpus = read_corpus(r't8.shakespeare.txt')

# %%
len(corpus)
# Out:
# 929396

# %%
vocab = set(corpus)
len(vocab)
# Out:
# 23902

# %%
words_count = Counter(corpus)
words_count
# Out:
# Counter({'this': 6853,
#          'is': 9784,
#          'the': 27660,
#          '100th': 1,
#          'etext': 245,
#          'file': 20,
#          'presented': 18,
#          'by': 4476,
#          'project': 251,
#          'gutenberg': 236,
#          'and': 26784,
#          'in': 11123,
#          'cooperation': 2,
#          'with': 8016,
#          'world': 905,
#          'library': 232,
#          'inc': 224,
#          'from': 2654,
#          'their': 2077,
#          'of': 18191,
#          'future': 17,
#          'shakespeare': 268,
#          'cdroms': 1,
#          'often': 124,
#          'releases': 1,
#          'etexts': 8,
#          'that': 11549,
#          'are': 3894,
#          'not': 8740,
#          'placed': 11,
#          'public': 57,
#          'domain': 4,
#          'has': 388,
#          'certain': 176,
#          'copyright': 228,
#          'implications': 1,
#          'you': 13860,
#          'should': 1580,
#          'read': 207,
#          'electronic': 443,
#          'version': 222,
#          'complete': 246,
#          'works': 249,
#          'william': 349,
#          '1990': 221,
#          '1993': 221,
#          'provided': 253,
#          'illinois': 223,
#          'benedictine': 223,
#          'college': 226,
#          'permission': 225,
#          'machine': 223,
#          'readable': 224,
#          'copies': 446,
#          'may': 1876,
#          'be': 7130,
#          'distributed': 443,
#          'so': 5282,
#          'long': 704,
#          'as': 5975,
#          'such': 1622,
#          '1': 309,
#          'for': 8341,
#          'your': 6885,
#          'or': 3127,
#          'others': 420,
#          'personal': 234,
#          'use': 548,
#          'only': 533,
#          '2': 301,
#          'used': 243,
#          'commercially': 221,
#          'prohibited': 221,
#          'commercial': 221,
#          'distribution': 224,
#          'includes': 223,
#          'any': 938,
#          'service': 444,
#          'charges': 237,
#          'download': 221,
#          'time': 1330,
#          'membership': 221,
#          'proud': 213,
#          'to': 19819,
#          'cooperate': 1,
#          'presentation': 4,
#          'reading': 34,
#          'education': 9,
#          'entertainment': 37,
#          'however': 13,
#          'neither': 186,
#          'shareware': 1,
#          'nor': 971,
#          'under': 298,
#          'conditions': 29,
#          'no': 3803,
#          'made': 837,
#          'access': 23,
#          'material': 6,
#          'encouraged': 3,
#          'give': 1351,
#          'it': 7737,
#          'away': 862,
#          'anyone': 2,
#          'like': 1788,
#          'but': 6282,
#          'allowed': 5,
#          'welcome': 366,
#          'free': 191,
#          'plain': 121,
#          'vanilla': 1,
#          'texts': 1,
#          'both': 645,
#          'humans': 1,
#          'computers': 1,
#          'since': 449,
#          '1971': 1,
#          'these': 1325,
#          'prepared': 12,
#          'hundreds': 4,
#          'volunteers': 1,
#          'donations': 4,
#          'information': 10,
#          'on': 3193,
#          'contacting': 1,
#          'get': 315,
#          'further': 190,
#          'included': 2,
#          'below': 54,
#          'we': 3624,
#          'need': 186,
#          'january': 3,
#          '1994': 1,
#          '100': 3,
#          'a': 14745,
#          'trademark': 1,
#          'tm': 3,
#          'named': 5,
#          'shaks12': 2,
#          'txt': 3,
#          'zip': 2,
#          'corrected': 3,
#          'editions': 1,
#          'our': 3068,
#          'new': 276,
#          'number': 55,
#          'shaks13': 1,
#          'versions': 1,
#          'based': 1,
#          'separate': 5,
#          'sources': 2,
#          'letter': 247,
#          'shaks10a': 1,
#          'if': 3521,
#          'would': 2301,
#          'about': 403,
#          'please': 396,
#          'call': 754,
#          'them': 1982,
#          'at': 2524,
#          '800': 1,
#          '443': 1,
#          '0238': 1,
#          'email': 3,
#          'julianc': 1,
#          'netcom': 1,
#          'com': 23,
#          'thanks': 172,
#          'official': 3,
#          'release': 8,
#          'date': 23,
#          'all': 3965,
#          'midnight': 43,
#          'central': 1,
#          'last': 269,
#          'day': 932,
#          'stated': 1,
#          'month': 44,
#          'preliminary': 1,
#          'posted': 7,
#          'suggestion': 10,
#          'comment': 14,
#          'editing': 1,
#          'those': 547,
#          'who': 1297,
#          'wish': 253,
#          'do': 3834,
#          'sure': 293,
#          'have': 5909,
#          'an': 1893,
#          'up': 1093,
#          'first': 1172,
#          'edition': 2,
#          'xxxxx10x': 1,
#          'xxx': 1,
#          'check': 35,
#          'sizes': 3,
#          'week': 29,
#          'next': 167,
#          'ftp': 4,
#          'program': 3,
#          'bug': 3,
#          'scrambles': 1,
#          'tried': 20,
#          'fix': 29,
#          'failed': 1,
#          'look': 939,
#          'size': 13,
#          'will': 5013,
#          'try': 93,
#          'see': 1462,
#          'copy': 18,
#          'least': 101,
#          'one': 1814,
#          'byte': 1,
#          'more': 2295,
#          'less': 224,
#          'page': 439,
#          'produce': 19,
#          'two': 714,
#          'million': 19,
#          'dollars': 3,
#          'each': 240,
#          'hour': 315,
#          'work': 197,
#          'fifty': 33,
#          'hours': 141,
#          'conservative': 1,
#          'estimate': 7,
#          'how': 2168,
#          'take': 1212,
#          'selected': 1,
#          'entered': 3,
#          'proofread': 1,
#          'edited': 1,
#          'searched': 1,
#          'analyzed': 1,
#          'letters': 131,
#          'written': 35,
#          'etc': 19,
#          'projected': 1,
#          'audience': 33,
#          'hundred': 115,
#          'readers': 2,
#          'value': 27,
#          'per': 6,
#          'text': 13,
#          'nominally': 1,
#          'estimated': 1,
#          'dollar': 2,
#          'then': 2224,
#          'year': 101,
#          'four': 152,
#          'files': 10,
#          'thus': 782,
#          'upping': 1,
#          'productivity': 1,
#          'goal': 4,
#          'trillion': 2,
#          'december': 8,
#          '31': 2,
#          '2001': 2,
#          '10': 5,
#          '000': 3,
#          'x': 5,
#          'ten': 156,
#          'thousand': 326,
#          'titles': 21,
#          'which': 2322,
#          'expected': 11,
#          'computer': 2,
#          'users': 2,
#          'end': 357,
#          'than': 1883,
#          'ever': 609,
#          'ibc': 3,
#          'tax': 17,
#          'deductible': 1,
#          'extent': 6,
#          'allowable': 1,
#          'law': 221,
#          'subscriptions': 1,
#          'paper': 106,
#          'newsletter': 1,
#          'go': 1742,
#          'too': 1236,
#          'other': 712,
#          'matters': 27,
#          'mail': 6,
#          'p': 11,
#          'o': 3055,
#          'box': 28,
#          '2782': 2,
#          'champaign': 2,
#          'il': 20,
#          '61825': 2,
#          'when': 2056,
#          'fails': 11,
#          'michael': 27,
#          's': 7723,
#          'hart': 17,
#          'executive': 1,
#          'director': 1,
#          'vmd': 4,
#          'cso': 5,
#          'uiuc': 5,
#          'edu': 5,
#          'internet': 6,
#          'uiucvmd': 2,
#          'bitnet': 3,
#          'prefer': 21,
#          'send': 262,
#          'compuserve': 3,
#          'attmail': 2,
#          'mcimail': 1,
#          'emulator': 2,
#          'directly': 34,
#          'archives': 1,
#          'mac': 1,
#          'point': 147,
#          'click': 1,
#          'type': 3,
#          'mrcnext': 1,
#          'login': 2,
#          'anonymous': 1,
#          'password': 1,
#          'cd': 5,
#          'etext91': 1,
#          'etext92': 1,
#          'etext93': 2,
#          'books': 39,
#          'now': 2793,
#          'also': 41,
#          'articles': 20,
#          'suggest': 8,
#          'gut': 4,
#          'dir': 2,
#          'mget': 2,
#          'set': 466,
#          'bin': 4,
#          '0index': 1,
#          'list': 61,
#          'general': 216,
#          'newsletters': 1,
#          'legal': 4,
#          'advisor': 1,
#          'small': 101,
#          'print': 22,
#          'unlike': 16,
#          'many': 579,
#          'protected': 4,
#          'materials': 1,
#          'methods': 2,
#          'effect': 72,
#          'reputation': 47,
#          'right': 352,
#          'distribute': 5,
#          'limited': 8,
#          'laws': 39,
#          'statement': 3,
#          'license': 9,
#          'b': 13,
#          'subject': 105,
#          'honor': 42,
#          'refund': 3,
#          'replacement': 3,
#          'provisions': 1,
#          'exact': 9,
#          'including': 6,
#          'can': 1217,
#          'compressed': 1,
#          'proprietary': 1,
#          'form': 117,
#          'resulting': 1,
#          'word': 503,
#          'processing': 1,
#          'hypertext': 2,
#          'software': 2,
#          'either': 172,
#          'displayed': 2,
#          'clearly': 6,
#          'does': 326,
#          'contain': 20,
#          'characters': 13,
#          'intended': 20,
#          'author': 17,
#          'although': 79,
#          'tilde': 1,
#          'asterisk': 1,
#          'underline': 1,
#          '_': 1,
#          'convey': 50,
#          'punctuation': 1,
#          'additional': 2,
#          'indicate': 1,
#          'links': 3,
#          'readily': 2,
#          'convertible': 1,
#          'reader': 2,
#          'expense': 19,
#          'into': 644,
#          'ascii': 2,
#          'ebcdic': 1,
#          'equivalent': 1,
#          'displays': 1,
#          'case': 111,
#          'instance': 26,
#          'most': 1183,
#          'processors': 1,
#          '3': 46,
#          'provide': 32,
#          'agree': 21,
#          'request': 67,
#          'cost': 48,
#          'fee': 36,
#          'warranty': 5,
#          'disclaimer': 1,
#          'damages': 5,
#          'defect': 15,
#          'incomplete': 1,
#          'inaccurate': 1,
#          'corrupt': 30,
#          'data': 1,
#          'transcription': 1,
#          'errors': 14,
#          'infringement': 1,
#          'defective': 6,
#          'damaged': 1,
#          'disk': 1,
#          'virus': 1,
#          'codes': 1,
#          'damage': 4,
#          'cannot': 762,
#          'equipment': 1,
#          'described': 2,
#          'party': 51,
#          'receive': 98,
#          'disclaims': 2,
#          'liability': 2,
#          'costs': 4,
#          'expenses': 3,
#          'fees': 6,
#          'remedies': 9,
#          'negligence': 15,
#          'strict': 17,
#          'breach': 35,
#          'contract': 28,
#          'indirect': 9,
#          'consequential': 1,
#          'punitive': 1,
#          'incidental': 1,
#          'even': 573,
#          'notice': 31,
#          'possibility': 4,
#          'discover': 43,
#          'within': 494,
#          '90': 2,
#          'days': 209,
#          'receiv': 61,
#          'ing': 1,
#          'money': 187,
#          'paid': 66,
#          'sending': 12,
#          'explanatory': 1,
#          'note': 152,
#          'person': 152,
#          'received': 28,
#          'physical': 3,
#          'medium': 2,
#          'must': 1492,
#          'return': 247,
#          'choose': 105,
#          'alternatively': 2,
#          'electronically': 2,
#          'second': 572,
#          'opportunity': 16,
#          'otherwise': 37,
#          'warranties': 3,
#          'kind': 282,
#          'express': 47,
#          'implied': 2,
#          'merchantability': 1,
#          'fitness': 10,
#          'particular': 56,
#          'purpose': 208,
#          'some': 1339,
#          'states': 15,
#          'allow': 48,
#          'disclaimers': 2,
#          'exclusion': 1,
#          'limitation': 3,
#          'consequen': 1,
#          'tial': 1,
#          'above': 147,
#          'exclusions': 1,
#          'apply': 16,
#          'rights': 23,
#          'indemnity': 1,
#          'indemnify': 1,
#          'hold': 468,
#          'its': 12,
#          'directors': 1,
#          'officers': 88,
#          'members': 11,
#          'agents': 4,
#          'harmless': 16,
#          'lia': 1,
#          'bility': 1,
#          'arise': 38,
#          'indirectly': 9,
#          'following': 52,
#          'cause': 338,
#          'alteration': 10,
#          'modification': 1,
#          'addition': 29,
#          'c': 25,
#          '4': 32,
#          'what': 4809,
#          'want': 143,
#          'don': 49,
#          't': 1213,
#          'dedicated': 4,
#          'increasing': 8,
#          'licensed': 1,
#          'freely': 55,
#          'gratefully': 1,
#          'accepts': 3,
#          'contributions': 1,
#          'scanning': 1,
#          'machines': 1,
#          'ocr': 1,
#          'royalty': 26,
#          'licenses': 1,
#          'whatever': 10,
#          'else': 417,
#          'think': 1074,
#          'pro': 2,
#          'ject': 1,
#          'association': 1,
#          'write': 125,
#          'us': 1678,
#          'reached': 1,
#          'prof': 1,
#          'charles': 126,
#          'kramer': 1,
#          'attorney': 9,
#          '72600': 1,
#          '2026': 1,
#          'tel': 1,
#          '212': 1,
#          '254': 1,
#          '5093': 1,
#          '__': 1,
#          'v': 99,
#          '12': 2,
#          '08': 1,
#          '93': 2,
#          '1609': 3,
#          'sonnets': 5,
#          'fairest': 42,
#          'creatures': 38,
#          'desire': 219,
#          'increase': 28,
#          'thereby': 26,
#          'beauty': 233,
#          'rose': 68,
#          'might': 500,
#          'never': 1020,
#          'die': 475,
#          'riper': 3,
#          'decease': 6,
#          'his': 6859,
#          'tender': 149,
#          'heir': 109,
#          'bear': 553,
#          'memory': 58,
#          'thou': 5549,
#          'contracted': 11,
#          'thine': 457,
#          'own': 772,
#          'bright': 72,
#          'eyes': 685,
#          'feed': 83,
#          'st': 1065,
#          'thy': 4034,
#          'light': 270,
#          'flame': 25,
#          'self': 212,
#          'substantial': 5,
#          'fuel': 5,
#          'making': 83,
#          'famine': 12,
#          'where': 1347,
#          'abundance': 13,
#          'lies': 245,
#          'foe': 63,
#          'sweet': 807,
#          'cruel': 72,
#          'art': 936,
#          'fresh': 90,
#          'ornament': 18,
#          'herald': 60,
#          'gaudy': 6,
#          'spring': 62,
#          'bud': 14,
#          'buriest': 1,
#          'content': 158,
#          'churl': 9,
#          'mak': 22,
#          'waste': 44,
#          'niggarding': 1,
#          'pity': 221,
#          'glutton': 4,
#          'eat': 143,
#          'due': 77,
#          'grave': 184,
#          'thee': 3181,
#          'forty': 30,
#          'winters': 10,
#          'shall': 3600,
#          'besiege': 10,
#          'brow': 73,
#          'dig': 11,
#          'deep': 150,
#          'trenches': 8,
#          'field': 192,
#          'youth': 283,
#          'livery': 21,
#          'gazed': 1,
#          'tattered': 3,
#          'weed': 18,
#          'worth': 205,
#          'held': 85,
#          'being': 664,
#          'asked': 4,
#          'treasure': 53,
#          'lusty': 36,
#          'say': 1758,
#          'sunken': 3,
#          'were': 1593,
#          'eating': 14,
#          'shame': 307,
#          'thriftless': 4,
#          'praise': 182,
#          'much': 1037,
#          'deserved': 20,
#          'couldst': 27,
#          'answer': 426,
#          'fair': 770,
#          'child': 242,
#          'mine': 1170,
#          'sum': 56,
#          'my': 12489,
#          'count': 132,
#          'make': 1637,
#          'old': 714,
#          'excuse': 78,
#          'proving': 1,
#          'succession': 17,
#          'blood': 667,
#          'warm': 51,
#          'feel': 108,
#          'cold': 202,
#          'glass': 68,
#          'tell': 1083,
#          'face': 423,
#          'viewest': 2,
#          'another': 455,
#          'whose': 618,
#          'repair': 46,
#          'renewest': 1,
#          'dost': 429,
#          'beguile': 24,
#          'unbless': 1,
#          'mother': 437,
#          'she': 2410,
#          'uneared': 1,
#          'womb': 55,
#          'disdains': 6,
#          'tillage': 1,
#          'husbandry': 14,
#          'he': 6679,
#          'fond': 58,
#          'tomb': 54,
#          'love': 2198,
#          'stop': 95,
#          'posterity': 11,
#          'calls': 92,
#          'back': 355,
#          'lovely': 53,
#          'april': 18,
#          'her': 3850,
#          'prime': 17,
#          'through': 263,
#          'windows': 19,
#          'age': 203,
#          'shalt': 295,
#          'despite': 52,
#          'wrinkles': 14,
#          'golden': 91,
#          'live': 514,
#          'remembered': 5,
#          'single': 59,
#          'image': 46,
#          'dies': 103,
#          'unthrifty': 5,
#          'loveliness': 2,
#          'why': 1476,
#          'spend': 68,
#          'upon': 1759,
#          'legacy': 5,
#          'nature': 385,
#          'bequest': 1,
#          'gives': 145,
#          'nothing': 636,
#          'doth': 940,
#          'lend': 93,
#          'frank': 13,
#          'lends': 13,
#          'beauteous': 39,
#          'niggard': 8,
#          'abuse': 47,
#          'bounteous': 18,
#          'largess': 5,
#          'given': 191,
#          'profitless': 3,
#          'usurer': 11,
#          'great': 921,
#          'sums': 17,
#          'yet': 1577,
#          'canst': 172,
#          'having': 156,
#          'traffic': 12,
#          'alone': 237,
#          'deceive': 28,
#          'gone': 466,
#          'acceptable': 1,
#          'audit': 9,
#          'leave': 657,
#          'unused': 5,
#          'tombed': 1,
#          'lives': 205,
#          'th': 1177,
#          'executor': 2,
#          '5': 20,
#          'gentle': 372,
#          'did': 1629,
#          'frame': 46,
#          'gaze': 27,
#          'every': 492,
#          'eye': 435,
#          'dwell': 41,
#          'play': 356,
#          'tyrants': 10,
#          'very': 813,
#          'same': 237,
#          'unfair': 1,
#          'fairly': 46,
#          'excel': 6,
#          'resting': 5,
#          'leads': 32,
#          'summer': 89,
#          'hideous': 22,
#          'winter': 73,
#          'confounds': 11,
#          'him': 5205,
#          'there': 2210,
#          'sap': 13,
#          'checked': 2,
#          'frost': 12,
#          'leaves': 72,
#          'quite': 86,
#          'er': 625,
#          'snowed': 1,
#          'bareness': 4,
#          'distillation': 2,
#          'left': 246,
#          'liquid': 9,
#          'prisoner': 83,
#          'pent': 11,
#          'walls': 85,
#          'bereft': 17,
#          'remembrance': 63,
#          'was': 2249,
#          'flowers': 46,
#          'distilled': 5,
#          'though': 634,
#          'they': 2531,
#          'meet': 327,
#          'leese': 1,
#          'show': 493,
#          'substance': 41,
#          'still': 564,
#          '6': 10,
#          'let': 2369,
#          'ragged': 24,
#          'hand': 854,
#          'deface': 4,
#          'ere': 366,
#          'vial': 5,
#          'place': 457,
#          'killed': 8,
#          'forbidden': 5,
#          'usury': 4,
#          'happies': 1,
#          'pay': 140,
#          'willing': 40,
#          'loan': 3,
#          'breed': 50,
#          'times': 208,
#          'happier': 17,
#          'refigured': 1,
#          'could': 627,
#          'death': 900,
#          'shouldst': 73,
#          'depart': 66,
#          'leaving': 25,
#          'living': 121,
#          'willed': 2,
#          'conquest': 31,
#          'worms': 23,
#          '7': 7,
#          'lo': 74,
#          'orient': 5,
#          'gracious': 198,
#          'lifts': 5,
#          'burning': 51,
#          'head': 537,
#          'homage': 17,
#          'appearing': 9,
#          'sight': 201,
#          'serving': 30,
#          'looks': 214,
#          'sacred': 47,
#          'majesty': 270,
#          'climbed': 1,
#          'steep': 23,
#          'heavenly': 55,
#          'hill': 42,
#          'resembling': 4,
#          'strong': 196,
#          'middle': 21,
#          'mortal': 98,
#          'adore': 14,
#          'attending': 43,
#          'pilgrimage': 16,
#          'highmost': 2,
#          'pitch': 36,
#          'weary': 78,
#          'car': 39,
#          'feeble': 37,
#          'reeleth': 1,
#          'fore': 44,
#          'duteous': 11,
#          'converted': 7,
#          'low': 106,
#          'tract': 4,
#          'way': 568,
#          'out': 1415,
#          'going': 109,
#          'noon': 17,
#          'unlooked': 2,
#          'diest': 22,
#          'unless': 153,
#          'son': 721,
#          '8': 3,
#          'music': 203,
#          'hear': 883,
#          'sadly': 18,
#          'sweets': 16,
#          'war': 272,
#          'joy': 196,
#          'delights': 20,
#          'lov': 165,
#          'gladly': 16,
#          'pleasure': 180,
#          'annoy': 9,
#          'true': 818,
#          'concord': 9,
#          'well': 2241,
#          'tuned': 6,
#          'sounds': 47,
#          'unions': 1,
#          'married': 152,
#          'offend': 60,
#          'ear': 199,
#          'sweetly': 27,
#          'chide': 49,
#          'singleness': 2,
#          'parts': 111,
#          'mark': 258,
#          'string': 8,
#          'husband': 327,
#          'strikes': 47,
#          'mutual': 15,
#          'ordering': 3,
#          'sire': 18,
#          'happy': 204,
#          'pleasing': 22,
#          'sing': 144,
#          'speechless': 13,
#          'song': 87,
#          'seeming': 62,
#          'sings': 91,
#          'wilt': 307,
#          'prove': 252,
#          'none': 469,
#          '9': 3,
#          'fear': 676,
#          'wet': 19,
#          'widow': 123,
#          'consum': 7,
#          'life': 862,
#          'ah': 183,
#          'issueless': 2,
#          'hap': 27,
#          'wail': 25,
#          'makeless': 1,
#          'wife': 542,
#          'weep': 171,
#          'hast': 585,
#          'behind': 120,
#          'private': 66,
#          'keep': 487,
#          'children': 123,
#          'shape': 87,
#          'mind': 366,
#          'unthrift': 3,
#          'shifts': 7,
#          'enjoys': 7,
#          'hath': 1942,
#          'kept': 98,
#          'user': 2,
#          'destroys': 2,
#          'toward': 103,
#          'bosom': 131,
#          'sits': 59,
#          'himself': 452,
#          'murd': 29,
#          'rous': 40,
#          'commits': 5,
#          'deny': 137,
#          'unprovident': 1,
#          'grant': 111,
#          'beloved': 31,
#          'evident': 7,
#          'possessed': 5,
#          'hate': 179,
#          'gainst': 101,
#          'stick': 32,
#          'conspire': 8,
#          'seeking': 24,
#          'roof': 18,
#          'ruinate': 2,
#          'chief': 108,
#          'change': 156,
#          'thought': 377,
#          'i': 22538,
#          'fairer': 38,
#          'lodged': 5,
#          'presence': 106,
#          'hearted': 38,
#          'me': 7777,
#          '11': 1,
#          'fast': 140,
#          'wane': 2,
#          'grow': 140,
#          'departest': 1,
#          'youngly': 2,
#          'bestow': 67,
#          'mayst': 68,
#          'convertest': 1,
#          'herein': 28,
#          'wisdom': 97,
#          'without': 368,
#          'folly': 80,
#          'decay': 26,
#          'minded': 18,
#          'cease': 47,
#          'threescore': 6,
#          'whom': 424,
#          'store': 40,
#          'harsh': 29,
#          'featureless': 1,
#          'rude': 73,
#          'barrenly': 1,
#          'perish': 34,
#          'best': 450,
#          'endowed': 2,
#          'gave': 232,
#          'gift': 66,
#          'bounty': 42,
#          'cherish': 26,
#          'carved': 6,
#          'seal': 96,
#          'meant': 53,
#          'clock': 86,
#          'tells': 42,
#          'brave': 160,
#          'sunk': 4,
#          ...})

# %%
total_words_count = float(sum(words_count.values()))

# %%
word_probabs = {word:words_count[word] / total_words_count for word in words_count.keys()}

# %%
word_probabs['the']
# Out:
# 0.029761264304989477

# %%
def split(word): # why
    return [ (word[:i], word[i:])  for i in range(len(word) + 1)]

# %%
print(split('shakespeare'))
# Out:
# [('', 'shakespeare'), ('s', 'hakespeare'), ('sh', 'akespeare'), ('sha', 'kespeare'), ('shak', 'espeare'), ('shake', 'speare'), ('shakes', 'peare'), ('shakesp', 'eare'), ('shakespe', 'are'), ('shakespea', 're'), ('shakespear', 'e'), ('shakespeare', '')]

# %%
def delete(word):
    return [left + right[1:] for left,right in split(word) if right]

# %%
print(delete('shakespeare'))
# Out:
# ['hakespeare', 'sakespeare', 'shkespeare', 'shaespeare', 'shakspeare', 'shakepeare', 'shakeseare', 'shakespare', 'shakespere', 'shakespeae', 'shakespear']

# %%
def swap(word):
    return [left + right[1] + right[0] + right[2:] for left,right in split(word) if len(right) > 1 ]

# %%
print(swap('shakespeare'))
# Out:
# ['hsakespeare', 'sahkespeare', 'shkaespeare', 'shaekspeare', 'shaksepeare', 'shakepseare', 'shakesepare', 'shakespaere', 'shakesperae', 'shakespeaer']

# %%
def replace(word): # abcdef...z
    return [left + center + right[1:] for left, right in split(word) if right for center in string.ascii_lowercase]

# %%
print(replace('shakespeare'))
# Out:
# ['ahakespeare', 'bhakespeare', 'chakespeare', 'dhakespeare', 'ehakespeare', 'fhakespeare', 'ghakespeare', 'hhakespeare', 'ihakespeare', 'jhakespeare', 'khakespeare', 'lhakespeare', 'mhakespeare', 'nhakespeare', 'ohakespeare', 'phakespeare', 'qhakespeare', 'rhakespeare', 'shakespeare', 'thakespeare', 'uhakespeare', 'vhakespeare', 'whakespeare', 'xhakespeare', 'yhakespeare', 'zhakespeare', 'saakespeare', 'sbakespeare', 'scakespeare', 'sdakespeare', 'seakespeare', 'sfakespeare', 'sgakespeare', 'shakespeare', 'siakespeare', 'sjakespeare', 'skakespeare', 'slakespeare', 'smakespeare', 'snakespeare', 'soakespeare', 'spakespeare', 'sqakespeare', 'srakespeare', 'ssakespeare', 'stakespeare', 'suakespeare', 'svakespeare', 'swakespeare', 'sxakespeare', 'syakespeare', 'szakespeare', 'shakespeare', 'shbkespeare', 'shckespeare', 'shdkespeare', 'shekespeare', 'shfkespeare', 'shgkespeare', 'shhkespeare', 'shikespeare', 'shjkespeare', 'shkkespeare', 'shlkespeare', 'shmkespeare', 'shnkespeare', 'shokespeare', 'shpkespeare', 'shqkespeare', 'shrkespeare', 'shskespeare', 'shtkespeare', 'shukespeare', 'shvkespeare', 'shwkespeare', 'shxkespeare', 'shykespeare', 'shzkespeare', 'shaaespeare', 'shabespeare', 'shacespeare', 'shadespeare', 'shaeespeare', 'shafespeare', 'shagespeare', 'shahespeare', 'shaiespeare', 'shajespeare', 'shakespeare', 'shalespeare', 'shamespeare', 'shanespeare', 'shaoespeare', 'shapespeare', 'shaqespeare', 'sharespeare', 'shasespeare', 'shatespeare', 'shauespeare', 'shavespeare', 'shawespeare', 'shaxespeare', 'shayespeare', 'shazespeare', 'shakaspeare', 'shakbspeare', 'shakcspeare', 'shakdspeare', 'shakespeare', 'shakfspeare', 'shakgspeare', 'shakhspeare', 'shakispeare', 'shakjspeare', 'shakkspeare', 'shaklspeare', 'shakmspeare', 'shaknspeare', 'shakospeare', 'shakpspeare', 'shakqspeare', 'shakrspeare', 'shaksspeare', 'shaktspeare', 'shakuspeare', 'shakvspeare', 'shakwspeare', 'shakxspeare', 'shakyspeare', 'shakzspeare', 'shakeapeare', 'shakebpeare', 'shakecpeare', 'shakedpeare', 'shakeepeare', 'shakefpeare', 'shakegpeare', 'shakehpeare', 'shakeipeare', 'shakejpeare', 'shakekpeare', 'shakelpeare', 'shakempeare', 'shakenpeare', 'shakeopeare', 'shakeppeare', 'shakeqpeare', 'shakerpeare', 'shakespeare', 'shaketpeare', 'shakeupeare', 'shakevpeare', 'shakewpeare', 'shakexpeare', 'shakeypeare', 'shakezpeare', 'shakesaeare', 'shakesbeare', 'shakesceare', 'shakesdeare', 'shakeseeare', 'shakesfeare', 'shakesgeare', 'shakesheare', 'shakesieare', 'shakesjeare', 'shakeskeare', 'shakesleare', 'shakesmeare', 'shakesneare', 'shakesoeare', 'shakespeare', 'shakesqeare', 'shakesreare', 'shakesseare', 'shakesteare', 'shakesueare', 'shakesveare', 'shakesweare', 'shakesxeare', 'shakesyeare', 'shakeszeare', 'shakespaare', 'shakespbare', 'shakespcare', 'shakespdare', 'shakespeare', 'shakespfare', 'shakespgare', 'shakesphare', 'shakespiare', 'shakespjare', 'shakespkare', 'shakesplare', 'shakespmare', 'shakespnare', 'shakespoare', 'shakesppare', 'shakespqare', 'shakesprare', 'shakespsare', 'shakesptare', 'shakespuare', 'shakespvare', 'shakespware', 'shakespxare', 'shakespyare', 'shakespzare', 'shakespeare', 'shakespebre', 'shakespecre', 'shakespedre', 'shakespeere', 'shakespefre', 'shakespegre', 'shakespehre', 'shakespeire', 'shakespejre', 'shakespekre', 'shakespelre', 'shakespemre', 'shakespenre', 'shakespeore', 'shakespepre', 'shakespeqre', 'shakesperre', 'shakespesre', 'shakespetre', 'shakespeure', 'shakespevre', 'shakespewre', 'shakespexre', 'shakespeyre', 'shakespezre', 'shakespeaae', 'shakespeabe', 'shakespeace', 'shakespeade', 'shakespeaee', 'shakespeafe', 'shakespeage', 'shakespeahe', 'shakespeaie', 'shakespeaje', 'shakespeake', 'shakespeale', 'shakespeame', 'shakespeane', 'shakespeaoe', 'shakespeape', 'shakespeaqe', 'shakespeare', 'shakespease', 'shakespeate', 'shakespeaue', 'shakespeave', 'shakespeawe', 'shakespeaxe', 'shakespeaye', 'shakespeaze', 'shakespeara', 'shakespearb', 'shakespearc', 'shakespeard', 'shakespeare', 'shakespearf', 'shakespe ...

# %%
def insert(word): # abcdef...z
    return [left + center + right[1:] for left, right in split(word) for center in string.ascii_lowercase]

# %%
print(replace('monkey'))
# Out:
# ['aonkey', 'bonkey', 'conkey', 'donkey', 'eonkey', 'fonkey', 'gonkey', 'honkey', 'ionkey', 'jonkey', 'konkey', 'lonkey', 'monkey', 'nonkey', 'oonkey', 'ponkey', 'qonkey', 'ronkey', 'sonkey', 'tonkey', 'uonkey', 'vonkey', 'wonkey', 'xonkey', 'yonkey', 'zonkey', 'mankey', 'mbnkey', 'mcnkey', 'mdnkey', 'menkey', 'mfnkey', 'mgnkey', 'mhnkey', 'minkey', 'mjnkey', 'mknkey', 'mlnkey', 'mmnkey', 'mnnkey', 'monkey', 'mpnkey', 'mqnkey', 'mrnkey', 'msnkey', 'mtnkey', 'munkey', 'mvnkey', 'mwnkey', 'mxnkey', 'mynkey', 'mznkey', 'moakey', 'mobkey', 'mockey', 'modkey', 'moekey', 'mofkey', 'mogkey', 'mohkey', 'moikey', 'mojkey', 'mokkey', 'molkey', 'momkey', 'monkey', 'mookey', 'mopkey', 'moqkey', 'morkey', 'moskey', 'motkey', 'moukey', 'movkey', 'mowkey', 'moxkey', 'moykey', 'mozkey', 'monaey', 'monbey', 'moncey', 'mondey', 'moneey', 'monfey', 'mongey', 'monhey', 'moniey', 'monjey', 'monkey', 'monley', 'monmey', 'monney', 'monoey', 'monpey', 'monqey', 'monrey', 'monsey', 'montey', 'monuey', 'monvey', 'monwey', 'monxey', 'monyey', 'monzey', 'monkay', 'monkby', 'monkcy', 'monkdy', 'monkey', 'monkfy', 'monkgy', 'monkhy', 'monkiy', 'monkjy', 'monkky', 'monkly', 'monkmy', 'monkny', 'monkoy', 'monkpy', 'monkqy', 'monkry', 'monksy', 'monkty', 'monkuy', 'monkvy', 'monkwy', 'monkxy', 'monkyy', 'monkzy', 'monkea', 'monkeb', 'monkec', 'monked', 'monkee', 'monkef', 'monkeg', 'monkeh', 'monkei', 'monkej', 'monkek', 'monkel', 'monkem', 'monken', 'monkeo', 'monkep', 'monkeq', 'monker', 'monkes', 'monket', 'monkeu', 'monkev', 'monkew', 'monkex', 'monkey', 'monkez']

# %%
def level_one_edits(word):
    return set((delete(word) + swap(word) + replace(word) + insert(word)))

# %%
print(level_one_edits('load'))
# Out:
# {'hoad', 'uoad', 'lotd', 'loxd', 'noad', 'loadb', 'liad', 'joad', 'lomd', 'loag', 'ltad', 'lgad', 'loae', 'laad', 'lokd', 'ooad', 'loar', 'ioad', 'lkad', 'lcad', 'loado', 'loaz', 'loan', 'voad', 'lead', 'lozd', 'lfad', 'poad', 'loas', 'luad', 'loadr', 'loam', 'doad', 'loaq', 'ljad', 'loda', 'loadh', 'loyd', 'loady', 'road', 'loadm', 'ldad', 'yoad', 'olad', 'lowd', 'lqad', 'toad', 'loadx', 'qoad', 'loade', 'soad', 'lnad', 'loap', 'goad', 'loao', 'loah', 'woad', 'loadi', 'loai', 'loadj', 'lrad', 'loax', 'lodd', 'loay', 'aoad', 'lzad', 'loadu', 'loaj', 'lpad', 'lood', 'lobd', 'lold', 'losd', 'loaa', 'lyad', 'loak', 'lod', 'lbad', 'laod', 'loud', 'lond', 'moad', 'lord', 'loadd', 'loadq', 'loa', 'lofd', 'lojd', 'koad', 'loada', 'lwad', 'loal', 'loadt', 'eoad', 'lmad', 'loads', 'lopd', 'lvad', 'loab', 'loadv', 'loadw', 'boad', 'loav', 'loid', 'loadp', 'zoad', 'lad', 'loac', 'loadf', 'loadz', 'loat', 'loadg', 'locd', 'loaw', 'loadk', 'loaf', 'oad', 'llad', 'loadc', 'loadn', 'lohd', 'lhad', 'load', 'foad', 'coad', 'xoad', 'loed', 'loadl', 'loau', 'logd', 'lsad', 'loqd', 'lxad', 'lovd'}

# %%
def level_two_edits(word):
    return set(e2  for e1 in level_one_edits(word) for e2 in level_one_edits(e1))

# %%
print(level_two_edits('cut'))
# Out:
# {'wutr', 'cutzt', 'uts', 'wmt', 'butw', 'ceu', 'lur', 'cuttm', 'bmt', 'zuty', 'zua', 'hutr', 'cutmm', 'vutl', 'cuvh', 'ilt', 'cok', 'rutu', 'ikt', 'cktk', 'cutis', 'cutxe', 'coi', 'cusr', 'ctq', 'curq', 'uup', 'csc', 'cufm', 'czb', 'cukv', 'cuxz', 'cuthk', 'cutzu', 'vlt', 'chtn', 'cg', 'okt', 'uus', 'zutn', 'cmo', 'uutd', 'cyh', 'rug', 'cpth', 'vum', 'cdn', 'chtm', 'cuthd', 'hutg', 'drt', 'vuv', 'dkt', 'xuk', 'cxo', 'cubx', 'dutp', 'hute', 'cut', 'csh', 'qup', 'sxt', 'cutpc', 'cyv', 'cutru', 'rot', 'chf', 'cuof', 'gutf', 'cal', 'cutdi', 'cukw', 'cutgj', 'cusw', 'cbl', 'ujt', 'cgo', 'cutw', 'cutod', 'qkt', 'xutn', 'cutmq', 'cfto', 'quty', 'dutm', 'cbtj', 'cuxd', 'uug', 'cktu', 'vuz', 'cnu', 'cap', 'cbtv', 'cuhi', 'vutd', 'cdi', 'cuac', 'cucs', 'ruty', 'cutah', 'cbtp', 'citd', 'duj', 'ckk', 'cuzi', 'rpt', 'cktl', 'nuw', 'bit', 'qutv', 'yutb', 'wutp', 'cbta', 'oxt', 'utx', 'cytn', 'guth', 'crtp', 'ckh', 'cuuv', 'suw', 'ctut', 'cusa', 'ou', 'cuttv', 'quts', 'cata', 'cutnx', 'cuak', 'hqt', 'wqt', 'hui', 'uuty', 'czf', 'cutpw', 'nute', 'cutir', 'rutd', 'ktt', 'wui', 'vuj', 'cuteo', 'jutc', 'nuto', 'ccti', 'cutiz', 'kt', 'cuqw', 'cuwl', 'ctuu', 'rnt', 'cqtu', 'cusq', 'clx', 'eug', 'cuiq', 'cukj', 'cuttr', 'cutyb', 'udt', 'cutqd', 'cktq', 'cetb', 'cudy', 'cuuw', 'cutsd', 'cptw', 'cuyq', 'coto', 'cix', 'prt', 'cuwu', 'fqt', 'cgtw', 'duc', 'luc', 'cotz', 'yutx', 'cutqp', 'cutxo', 'wutl', 'zutp', 'lutx', 'cutqx', 'hun', 'mutj', 'uutr', 'putx', 'cutwb', 'citb', 'kyt', 'hst', 'eue', 'gutq', 'juta', 'cutdu', 'uutc', 'cuos', 'alt', 'hu', 'cutxk', 'dutt', 'cudj', 'curg', 'cqtd', 'cutv', 'ucb', 'cutvi', 'cutng', 'utk', 'mub', 'nnt', 'vjt', 'cpty', 'cfy', 'cuin', 'cusl', 'cutsh', 'cuvu', 'cuzv', 'utl', 'cci', 'iqt', 'cyty', 'cutac', 'eutx', 'yuz', 'czv', 'act', 'ext', 'cltr', 'suf', 'tutt', 'cytz', 'iua', 'suts', 'cxtb', 'juy', 'ccta', 'azt', 'cjth', 'qutu', 'zqt', 'cbu', 'gpt', 'ckty', 'duta', 'bzt', 'cutwm', 'dutj', 'cfp', 'cmtr', 'eutd', 'catp', 'lmt', 'cytu', 'cqr', 'futk', 'cupl', 'nue', 'cutce', 'cktb', 'cptd', 'cutnk', 'cutwz', 'eutp', 'ctm', 'wnt', 'cbtr', 'cetn', 'co', 'oat', 'tuth', 'xutu', 'cutdr', 'cuqp', 'cutbo', 'eit', 'cqy', 'ost', 'putv', 'citv', 'cza', 'clj', 'cntn', 'cutjb', 'cqn', 'yux', 'ywt', 'oul', 'iutr', 'xutw', 'cjtn', 'cutws', 'vur', 'cpj', 'cdu', 'crtb', 'cuwr', 'cqtx', 'yzt', 'mdt', 'vat', 'vuc', 'czr', 'crx', 'bjt', 'cuon', 'qutg', 'rub', 'cutqv', 'tutc', 'xt', 'outj', 'qvt', 'cltl', 'cuoh', 'ucta', 'cuttg', 'cuoq', 'cuttd', 'ljt', 'cuttk', 'huts', 'qum', 'cls', 'uctf', 'pet', 'vut', 'csr', 'cuqc', 'cutxn', 'nuty', 'wtu', 'cvd', 'cuog', 'cuthc', 'cvth', 'cbx', 'xuu', 'cuwg', 'buty', 'wub', 'cudf', 'cued', 'njt', 'lnt', 'duto', 'mug', 'ztu', 'mutn', 'ca', 'cgh', 'cmr', 'cuwz', 'chu', 'ucu', 'cuzs', 'cukg', 'crv', 'cutfl', 'cuxr', 'cns', 'wyt', 'cztu', 'kur', 'clu', 'cuwm', 'citc', 'cuttn', 'cutxs', 'cwti', 'vul', 'rud', 'dnt', 'cbtb', 'buh', 'ckl', 'vutx', 'cuzm', 'cupu', 'cuhp', 'cutpo', 'cdf', 'cyti', 'sutu', 'culw', 'luh', 'mutf', 'cutln', 'pit', 'xue', 'nuf', 'mot', 'cds', 'qutw', 'cuyp', 'cstp', 'cxq', 'cqg', 'muth', 'luy', 'cutdy', 'us', 'ous', 'wtt', 'cutdh', 'nutf', 'cuthw', 'cutsq', 'ttu', 'cetu', 'chtf', 'cac', 'cutdl', 'cwn', 'citr', 'zub', 'cutsz', 'jutu', 'cutaa', 'cutzy', 'pyt', 'muj', 'cntv', 'ccr', 'cucl', 'cgtd', 'cutms', 'chk', 'wua', 'luta', 'cugz', 'cutcn', 'dyt', 'uuj', 'wuy', 'tutd', 'cab', 'cuup', 'futf', 'ul', 'futc', 'lrt', 'duk', 'crtv', 'cuxe', 'cltq', 'cqtl', 'cutyp', 'cwx', 'ccd', 'cctr', 'fuq', 'cuk', 'cm', 'jus', 'guta', 'iutw', 'ckg', 'crw', 'cutdm', 'cxa', 'xuy', 'cetz', 'gutz', 'eur', 'nuh', 'euty', 'cutig', 'utf', 'nuo', 'guv', 'cuwd', 'col', 'cutld', 'huta', 'rbt', 'puth', 'dit', 'ccu', 'cgte', 'cltj', 'mxt', 'cgn', 'au', 'cuthx', 'suy', 'cutnf', 'sft', 'cen', 'fuj', 'cutwf', 'ccc', 'cuds', 'cufk', 'cko', 'akt', 'ntu', 'wuf', 'ctul', 'rutz', 'cutqw', 'cgtn', 'cits', 'cwtn', 'clc', 'cvu', 'coe', 'cuyo', 'uuth', 'krt', 'eutb', 'cytc', 'cutsb', 'ugt', 'xlt', 'cuan', 'cftr', 'cktz', 'a ...

# %%
def correct_spelling(word,vocab,word_probabs):
    if word in vocab:
        print(f"{word} is already correctly spelled")
        return 
    #getting all suggesions
    suggestions = level_one_edits(word) or level_two_edits(word) or [word]
    best_guesses = [w for w in suggestions if w in vocab]
    return [(w, word_probabs[w]) for w in best_guesses]

# %%
search_word = "willima"
guess = correct_spelling(search_word,vocab,word_probabs)
print(guess)
# Out:
# [('william', 0.00037551269856982383)]
